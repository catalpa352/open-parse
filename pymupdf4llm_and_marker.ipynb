# %% [markdown]
# # pymupdf4llm:

# %%
# !pip install -U pymupdf4llm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 64.8 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/google/colab/_pip.py:86: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/pymupdf4llm-0.0.17.dist-info/top_level.txt' mode='r' encoding='UTF-8'>
#   for line in open(toplevel):
# ...

# %%
import pymupdf4llm

md_text = pymupdf4llm.to_markdown("/content/ppt_to_pdf.pdf")

# now work with the markdown text, e.g. store as a UTF8-encoded file
import pathlib
pathlib.Path("output.md").write_bytes(md_text.encode())
# Out:
# Processing /content/ppt_to_pdf.pdf...
# ]
# 351

# %% [markdown]
# **Conclusion:** convert pdf to markdown,only texts and tables

# %% [markdown]
# # Marker:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# put this page of pdf in tools result: can't parse the image

# %%
-
-
- 沃尔沃i

![](_page_0_Picture_3.jpeg)

![](_page_0_Picture_4.jpeg)

# %% [markdown]
# put three page of whole pdf in tools result: can parse the image

# %%
![](_page_0_Picture_0.jpeg)

-
-
- · 沃尔沃i

![](_page_1_Picture_3.jpeg)

人人自觉 / 认真细致 / 废物利用 / 节能环保

# 垃圾不落地

# 城市更美丽

做好垃圾分类·让和谐城市微笑

做好垃圾分类·共创文明新风

垃圾分类,指按一定规定或标准将垃圾分类储存、分类投放和分类搬运,从而转变成公共资源的一系列活动的总称。分类的目的是提高垃圾的资源价值和经济价值,力争物尽其用。

Garbage classification refers to the classification, storage, delivery and handling of garbage in accordance with certain regulations or standards, thus transforming it into a system of public resources.General name of column activities. The purpose of classification is to improve the resource value andeconomic value of garbage, and strive to make the best use of everything.

可回收垃圾

其他垃圾

有害垃圾

厨房垃圾

-
-
-

|                                | 你好     | 额外跳舞 | 而特 |                                   |
|--------------------------------|--------|------|----|-----------------------------------|
| • deepseek<br>• 男孩女孩<br>• 沃尔沃i | 问题为你说啥 | 胎儿臀位 | 如图 | • deepseek<br>• 问题为为而为人<br>• 为而结尾 |
|                                | 数据而结尾  | 而为   | 玩儿 |                                   |
|                                | 问题     | 玩儿   | 而特 |                                   |

-
-

$$
\bullet \not\cong \boxplus \upsharp \models \boxplus \boxplus
$$

# %% [markdown]
# ## conclusion:
# 1.pdf can converted to html,markdown,json
#
# 2.LLM could not use to extract content from images
#
# 3.texts and tables can be extracted
#
# 4.Images are not always parsed
#
# 4.support command line and visual interface
